# %% [markdown]
# # Perceptron plotting function

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_perceptron_regression(samples, labels, weights, x_range):
    # Plot style
    plt.axis('equal')
    plt.axhline(0, color='black', linewidth=.5)
    plt.axvline(0, color='black', linewidth=.5)
    plt.xlabel('x1')
    plt.ylabel('x2')
    ax = plt.gca()
    ax.set_xlim([x_range[0], x_range[1]])
    ax.set_ylim([x_range[0], x_range[1]])

    # Linear axis computation
    x1 = np.linspace(x_range[0], x_range[1], 100)
    x2 = - (weights[0] + weights[1] * x1) / weights[2]

    # Input data plot
    plt.plot(x1, x2)
    for i, sample in enumerate(samples):
        plt.plot(sample[0], sample[1], "bo" if labels[i] == 1 else "ro")

    plt.show()

def display_mse(perceptron, y_lim):
    mse = perceptron.mse
    print(f"Minimum atteint: {min(mse)}")
    len(mse)

    plt.figure(figsize=(5, 5))
    plt.plot(range(len(mse)), mse)
    plt.ylim(0, y_lim)
    plt.grid()

    plt.xlabel("Number of Epochs")
    plt.ylabel("Mean Square Error")

# %% [markdown]
# # Adaline Perceptron learning AND gate

# %%
import quark

samples = [[0, 0], [0, 1], [1, 0], [1, 1]]
labels = [-1, -1, -1, 1]

perceptron = quark.AdalinePerceptron(2, 0.03, False, "Step")
perceptron.train(samples, labels, 50)

print(perceptron.weights)

plot_perceptron_regression(samples, labels, perceptron.weights, [-0.5, 2])
# Out:
# [-0.9952719016360491, 0.6083372420151226, 0.5929990785436918]

# %%
import matplotlib.pyplot as plt

mse = perceptron.mse
print(f"Minimum atteint: {min(mse)}")
len(mse)

plt.figure(figsize=(5, 5))
plt.plot(range(len(mse)), mse)
plt.ylim(0, 1.0)
plt.grid()

plt.xlabel("Number of Epochs")
plt.ylabel("Mean Square Error")
# Out:
# Minimum atteint: 0.1704353689253344
# Text(0, 0.5, 'Mean Square Error')

# %% [markdown]
# # Adaline Perceptron learning OR gate

# %%
samples = [[0, 0], [0, 1], [1, 0], [1, 1]]
labels = [-1, 1, 1, 1]

perceptron = quark.AdalinePerceptron(2, 0.03, False, "Step")
perceptron.train(samples, labels, 50)

print(perceptron.weights)

plot_perceptron_regression(samples, labels, perceptron.weights, [-0.5, 2])
# Out:
# [-0.14042419565334957, 0.6916949260556865, 0.7027977309675438]

# %%
import matplotlib.pyplot as plt

mse = perceptron.mse
print(f"Minimum atteint: {min(mse)}")
len(mse)

plt.figure(figsize=(5, 5))
plt.plot(range(len(mse)), mse)
plt.ylim(0, 0.4)
plt.grid()

plt.xlabel("Number of Epochs")
plt.ylabel("Mean Square Error")
# Out:
# Minimum atteint: 0.14953702830851232
# Text(0, 0.5, 'Mean Square Error')

# %% [markdown]
# # Adaline Perceptron learning XOR gate

# %%
samples = [[0, 0], [0, 1], [1, 0], [1, 1]]
labels = [-1, 1, 1, -1]

perceptron = quark.AdalinePerceptron(2, 0.03, True, "Step")
perceptron.train(samples, labels, 100)

print(perceptron.weights)

plot_perceptron_regression(samples, labels, perceptron.weights, [-0.5, 2])
# Out:
# [0.019290976146451668, -0.060024939601510896, -0.013742612125607932]

# %%
import matplotlib.pyplot as plt

mse = perceptron.mse
print(f"Minimum atteint: {min(mse)}")
len(mse)

plt.figure(figsize=(5, 5))
plt.plot(range(len(mse)), mse)
plt.ylim(0, 1.0)
plt.grid()

plt.xlabel("Number of Epochs")
plt.ylabel("Mean Square Error")
# Out:
# Minimum atteint: 0.5006287348962182
# Text(0, 0.5, 'Mean Square Error')

# %% [markdown]
# # Adaline Perceptron learning sample 2.9

# %%
import quark
import pandas as pd

df = pd.read_csv("datasets/table_2_9.csv", header=None)
samples = df.iloc[:, :2].values.tolist()
labels = df.iloc[:, 2].values.tolist()
labelsFormatted = list()
for i in labels:
    if(i == 0):
        labelsFormatted.append(-1)
    else:
        labelsFormatted.append(1)

perceptron = quark.AdalinePerceptron(2, 0.0011, False, "Step")
perceptron.train(samples, labelsFormatted, 2000)

print(perceptron.weights)

plot_perceptron_regression(samples, labelsFormatted, perceptron.weights, [0, 14])
# Out:
# [-1.7805576553925955, -0.5238866869390078, 0.48439354308022814]

# %%
import matplotlib.pyplot as plt

mse = perceptron.mse
print(f"Minimum atteint: {min(mse)}")
len(mse)

plt.figure(figsize=(5, 5))
plt.plot(range(len(mse)), mse)
plt.ylim(0, 1.0)
plt.grid()

plt.xlabel("Number of Epochs")
plt.ylabel("Mean Square Error")
# Out:
# Minimum atteint: 0.09019326091187463
# Text(0, 0.5, 'Mean Square Error')

# %% [markdown]
# # Adaline Perceptron learning table 2.10

# %%
import quark
import pandas as pd

df = pd.read_csv("datasets/table_2_10.csv", header=None)
samples = df.iloc[:, :2].values.tolist()
labels = df.iloc[:, 2].values.tolist()
labelsFormatted = list()
for i in labels:
    if(i == 0):
        labelsFormatted.append(-1)
    else:
        labelsFormatted.append(1)
        
perceptron = quark.AdalinePerceptron(2, 0.0015, False, "Step")
perceptron.train(samples, labelsFormatted, 1000)

print(perceptron.weights)

plot_perceptron_regression(samples, labels, perceptron.weights, [0, 8])
# Out:
# [-0.02267341157610299, -0.2542199638969986, 0.2949549829993353]

# %%
import matplotlib.pyplot as plt

mse = perceptron.mse
print(f"Minimum atteint: {min(mse)}")
len(mse)

plt.figure(figsize=(5, 5))
plt.plot(range(len(mse)), mse)
plt.ylim(0, 1.0)
plt.grid()

plt.xlabel("Number of Epochs")
plt.ylabel("Mean Square Error")
# Out:
# Minimum atteint: 0.3608060191491378
# Text(0, 0.5, 'Mean Square Error')

# %% [markdown]
# # Adaline Perceptron learning table 2.11

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("datasets/table_2_11.csv")

samples = df[["x1"]].values.tolist()
labels = df["d"].values.tolist()

plt.figure(figsize=(5,5))
plt.scatter(samples, labels, marker='o', color='b')

# %%
perceptron = quark.AdalinePerceptron(1, 0.0001, False, "Linear")
perceptron.train(samples, labels, 20)

# %%
display_mse(perceptron, 4.0)
# Out:
# Minimum atteint: 0.6739136826687093

# %%
import matplotlib.pyplot as plt
import numpy as np

xlim = [8, 30]
ylim = [4, 12]
step = 0.1

plt.figure(figsize=(5, 5))

f2 = np.vectorize(perceptron.predict)

X = np.linspace(xlim[0], xlim[1], 100)
Y = []
for x in X:
    Y.append(perceptron.predict([x]))

plt.plot(X, Y)

for sample in df.values:
    plt.scatter(sample[0],sample[1], marker='o', color='g')

plt.xlim(xlim[0], xlim[1])
plt.ylim(ylim[0], ylim[1])
plt.grid()

plt.xlabel("x1")
plt.ylabel("x2")
# Out:
# Text(0, 0.5, 'x2')
